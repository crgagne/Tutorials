# %% [markdown]
# # Getting Started with OpenAI's Gym
#
# -

# %%
import gym
env = gym.make('CartPole-v0')
env.reset()
for _ in range(1000):
    env.render()
    env.step(env.action_space.sample()) # take a random action
# Out:
# [2017-06-13 09:12:47,390] Making new env: CartPole-v0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-c13d11cabe05> in <module>()
#       3 env.reset()
#       4 for _ in range(1000):
# ----> 5     env.render()
#       6     env.step(env.action_space.sample()) # take a random action
#
# /home/bishop/cgagne/Proj_Tutorials/gym/gym/core.py in render(self, mode, close)
#     151             elif mode not in modes:
#     152                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 153         return self._render(mode=mode, close=close)
#     154
#     155     def close(self):
#
# /home/bishop/cgagne/Proj_Tutorials/gym/gym/core.py in _render(self, mode, close)
#     283
#     284     def _render(self, mode='human', close=False):
# --> 285         return self.env.render(mode, close)
# ...
